# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib.pyplot import xticks
from matplotlib.pyplot import xticks

# %%
df=pd.read_csv('Salary Data.csv')
df
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
df.drop(["Job Title"],axis= 1 , inplace =True)
df
# Out:
#       Age  Gender Education Level  Years of Experience    Salary
# 0    32.0    Male      Bachelor's                  5.0   90000.0
# 1    28.0  Female        Master's                  3.0   65000.0
# 2    45.0    Male             PhD                 15.0  150000.0
# 3    36.0  Female      Bachelor's                  7.0   60000.0
# 4    52.0    Male        Master's                 20.0  200000.0
# ..    ...     ...             ...                  ...       ...
# 370  35.0  Female      Bachelor's                  8.0   85000.0
# 371  43.0    Male        Master's                 19.0  170000.0
# 372  29.0  Female      Bachelor's                  2.0   40000.0
# 373  34.0    Male      Bachelor's                  7.0   90000.0
# 374  44.0  Female             PhD                 15.0  150000.0
#
# [375 rows x 5 columns]

# %%
df.describe()
# Out:
#               Age  Years of Experience         Salary
# count  373.000000           373.000000     373.000000
# mean    37.431635            10.030831  100577.345845
# std      7.069073             6.557007   48240.013482
# min     23.000000             0.000000     350.000000
# 25%     31.000000             4.000000   55000.000000
# 50%     36.000000             9.000000   95000.000000
# 75%     44.000000            15.000000  140000.000000
# max     53.000000            25.000000  250000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375 entries, 0 to 374
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    object
#  2   Education Level      373 non-null    object
#  3   Years of Experience  373 non-null    float64
#  4   Salary               373 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 14.8+ KB

# %%
df.isna().sum()
# Out:
# Age                    2
# Gender                 2
# Education Level        2
# Years of Experience    2
# Salary                 2
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isna().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Years of Experience    0
# Salary                 0
# dtype: int64

# %%
df.head()
# Out:
#     Age  Gender Education Level  Years of Experience    Salary
# 0  32.0    Male      Bachelor's                  5.0   90000.0
# 1  28.0  Female        Master's                  3.0   65000.0
# 2  45.0    Male             PhD                 15.0  150000.0
# 3  36.0  Female      Bachelor's                  7.0   60000.0
# 4  52.0    Male        Master's                 20.0  200000.0

# %%
df_no_of_mf=pd.DataFrame(df['Gender'].value_counts())
df_no_of_mf
df_no_of_mf.plot.pie(subplots=True,label=df_no_of_mf.index.values,figsize=(10,7),autopct='%1.1f%%')
# Out:
# array([<Axes: ylabel='Gender'>], dtype=object)

# %%
df.head()
# Out:
#     Age  Gender Education Level  Years of Experience    Salary
# 0  32.0    Male      Bachelor's                  5.0   90000.0
# 1  28.0  Female        Master's                  3.0   65000.0
# 2  45.0    Male             PhD                 15.0  150000.0
# 3  36.0  Female      Bachelor's                  7.0   60000.0
# 4  52.0    Male        Master's                 20.0  200000.0

# %%
df_as=df[["Age","Salary"]].groupby("Age").mean().plot(kind="bar",legend=True,figsize=(15,10))
plt.xlabel("Age")
plt.ylabel("Avg salary")
xticks(rotation=45)
plt.show()

# %%
df.head()
# Out:
#     Age  Gender Education Level  Years of Experience    Salary
# 0  32.0    Male      Bachelor's                  5.0   90000.0
# 1  28.0  Female        Master's                  3.0   65000.0
# 2  45.0    Male             PhD                 15.0  150000.0
# 3  36.0  Female      Bachelor's                  7.0   60000.0
# 4  52.0    Male        Master's                 20.0  200000.0

# %%
df_JT_S=df[['Education Level','Salary']].groupby("Education Level").mean().plot(kind='bar',legend=True,figsize=(15,9))

# %%
df.head()
# Out:
#     Age  Gender Education Level  Years of Experience    Salary
# 0  32.0    Male      Bachelor's                  5.0   90000.0
# 1  28.0  Female        Master's                  3.0   65000.0
# 2  45.0    Male             PhD                 15.0  150000.0
# 3  36.0  Female      Bachelor's                  7.0   60000.0
# 4  52.0    Male        Master's                 20.0  200000.0

# %%
df_G_S=df[["Gender",'Salary']].groupby("Gender").mean().plot(kind='bar',subplots=True,figsize=(15,9))
plt.xlabel("Gender")
plt.ylabel("Avg salary ")
xticks(rotation=45)
plt.show()

# %%
df.head()
# Out:
#     Age  Gender Education Level  Years of Experience    Salary
# 0  32.0    Male      Bachelor's                  5.0   90000.0
# 1  28.0  Female        Master's                  3.0   65000.0
# 2  45.0    Male             PhD                 15.0  150000.0
# 3  36.0  Female      Bachelor's                  7.0   60000.0
# 4  52.0    Male        Master's                 20.0  200000.0

# %%
df_G_S=df[["Age",'Gender']].groupby("Gender").mean().plot(kind='bar',subplots=True,figsize=(10,6))
plt.xlabel("Gender")
plt.ylabel("Age ")
xticks(rotation=45)
plt.show()

# %%
df.head()
# Out:
#     Age  Gender Education Level  Years of Experience    Salary
# 0  32.0    Male      Bachelor's                  5.0   90000.0
# 1  28.0  Female        Master's                  3.0   65000.0
# 2  45.0    Male             PhD                 15.0  150000.0
# 3  36.0  Female      Bachelor's                  7.0   60000.0
# 4  52.0    Male        Master's                 20.0  200000.0

# %%
# len(df[(df["Gender"]=="Female") & (df['Job Title']=="Data Analyst")])

# %%
len(df[(df["Gender"]=="Male") & (df['Salary']>=100000)])
# Out:
# 97

# %%
len(df[(df["Gender"]=="Female") & (df['Salary']>=100000)])
# Out:
# 79

# %%
df.head()
# Out:
#     Age  Gender Education Level  Years of Experience    Salary
# 0  32.0    Male      Bachelor's                  5.0   90000.0
# 1  28.0  Female        Master's                  3.0   65000.0
# 2  45.0    Male             PhD                 15.0  150000.0
# 3  36.0  Female      Bachelor's                  7.0   60000.0
# 4  52.0    Male        Master's                 20.0  200000.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 373 entries, 0 to 374
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  373 non-null    float64
#  1   Gender               373 non-null    object
#  2   Education Level      373 non-null    object
#  3   Years of Experience  373 non-null    float64
#  4   Salary               373 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 17.5+ KB

# %%
auto=df[['Age','Gender','Education Level','Years of Experience','Salary']]
auto
# Out:
#       Age  Gender Education Level  Years of Experience    Salary
# 0    32.0    Male      Bachelor's                  5.0   90000.0
# 1    28.0  Female        Master's                  3.0   65000.0
# 2    45.0    Male             PhD                 15.0  150000.0
# 3    36.0  Female      Bachelor's                  7.0   60000.0
# 4    52.0    Male        Master's                 20.0  200000.0
# ..    ...     ...             ...                  ...       ...
# 370  35.0  Female      Bachelor's                  8.0   85000.0
# 371  43.0    Male        Master's                 19.0  170000.0
# 372  29.0  Female      Bachelor's                  2.0   40000.0
# 373  34.0    Male      Bachelor's                  7.0   90000.0
# 374  44.0  Female             PhD                 15.0  150000.0
#
# [373 rows x 5 columns]

# %%
sns.pairplot(auto)
plt.show()

# %%
df.head()
# Out:
#     Age  Gender Education Level  Years of Experience    Salary
# 0  32.0    Male      Bachelor's                  5.0   90000.0
# 1  28.0  Female        Master's                  3.0   65000.0
# 2  45.0    Male             PhD                 15.0  150000.0
# 3  36.0  Female      Bachelor's                  7.0   60000.0
# 4  52.0    Male        Master's                 20.0  200000.0

# %%
Sex=pd.get_dummies(auto['Gender'],drop_first=True)
auto=pd.concat([auto,Sex],axis=1)
auto
# Out:
#       Age  Gender Education Level  Years of Experience    Salary  Male
# 0    32.0    Male      Bachelor's                  5.0   90000.0     1
# 1    28.0  Female        Master's                  3.0   65000.0     0
# 2    45.0    Male             PhD                 15.0  150000.0     1
# 3    36.0  Female      Bachelor's                  7.0   60000.0     0
# 4    52.0    Male        Master's                 20.0  200000.0     1
# ..    ...     ...             ...                  ...       ...   ...
# 370  35.0  Female      Bachelor's                  8.0   85000.0     0
# 371  43.0    Male        Master's                 19.0  170000.0     1
# 372  29.0  Female      Bachelor's                  2.0   40000.0     0
# 373  34.0    Male      Bachelor's                  7.0   90000.0     1
# 374  44.0  Female             PhD                 15.0  150000.0     0
#
# [373 rows x 6 columns]

# %%
Education_level=pd.get_dummies(auto['Education Level'])
auto=pd.concat([auto,Education_level],axis=1)
auto
# Out:
#       Age  Gender Education Level  Years of Experience    Salary  Male  \
# 0    32.0    Male      Bachelor's                  5.0   90000.0     1
# 1    28.0  Female        Master's                  3.0   65000.0     0
# 2    45.0    Male             PhD                 15.0  150000.0     1
# 3    36.0  Female      Bachelor's                  7.0   60000.0     0
# 4    52.0    Male        Master's                 20.0  200000.0     1
# ..    ...     ...             ...                  ...       ...   ...
# 370  35.0  Female      Bachelor's                  8.0   85000.0     0
# 371  43.0    Male        Master's                 19.0  170000.0     1
# 372  29.0  Female      Bachelor's                  2.0   40000.0     0
# 373  34.0    Male      Bachelor's                  7.0   90000.0     1
# 374  44.0  Female             PhD                 15.0  150000.0     0
#
#      Bachelor's  Master's  PhD
# 0             1         0    0
# 1             0         1    0
# ...

# %%
auto.drop(['Gender','Education Level'],axis=1,inplace=True)

# %%
auto
# Out:
#       Age  Years of Experience    Salary  Male  Bachelor's  Master's  PhD
# 0    32.0                  5.0   90000.0     1           1         0    0
# 1    28.0                  3.0   65000.0     0           0         1    0
# 2    45.0                 15.0  150000.0     1           0         0    1
# 3    36.0                  7.0   60000.0     0           1         0    0
# 4    52.0                 20.0  200000.0     1           0         1    0
# ..    ...                  ...       ...   ...         ...       ...  ...
# 370  35.0                  8.0   85000.0     0           1         0    0
# 371  43.0                 19.0  170000.0     1           0         1    0
# 372  29.0                  2.0   40000.0     0           1         0    0
# 373  34.0                  7.0   90000.0     1           1         0    0
# 374  44.0                 15.0  150000.0     0           0         0    1
#
# [373 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
df_train,df_test=train_test_split(auto,train_size=0.7,test_size=0.3,random_state=100)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
num_vars=["Age",'Years of Experience','Salary']
df_train[num_vars]=scaler.fit_transform(df_train[num_vars])

# %%
df_train
# Out:
#           Age  Years of Experience    Salary  Male  Bachelor's  Master's  PhD
# 26   0.482759                 0.44  0.363636     0           0         1    0
# 174  0.103448                 0.06  0.068182     0           0         1    0
# 35   0.137931                 0.08  0.068182     1           1         0    0
# 262  0.793103                 0.72  0.590909     1           0         0    1
# 39   0.896552                 0.84  0.590909     1           1         0    0
# ..        ...                  ...       ...   ...         ...       ...  ...
# 345  0.344828                 0.16  0.136364     1           1         0    0
# 361  0.379310                 0.28  0.272727     1           1         0    0
# 325  0.448276                 0.36  0.318182     1           1         0    0
# 282  0.827586                 0.76  0.636364     1           0         1    0
# 8    0.103448                 0.04  0.068182     0           1         0    0
#
# [261 rows x 7 columns]

# %%
plt.figure(figsize=(15,9))
sns.heatmap(df_train.corr(),annot=True)
plt.show()

# %%
y_train=df_train.pop("Salary")
x_train=df_train

# %%
y_train
# Out:
# 26     0.363636
# 174    0.068182
# 35     0.068182
# 262    0.590909
# 39     0.590909
#          ...
# 345    0.136364
# 361    0.272727
# 325    0.318182
# 282    0.636364
# 8      0.068182
# Name: Salary, Length: 261, dtype: float64

# %%
x_train
# Out:
#           Age  Years of Experience  Male  Bachelor's  Master's  PhD
# 26   0.482759                 0.44     0           0         1    0
# 174  0.103448                 0.06     0           0         1    0
# 35   0.137931                 0.08     1           1         0    0
# 262  0.793103                 0.72     1           0         0    1
# 39   0.896552                 0.84     1           1         0    0
# ..        ...                  ...   ...         ...       ...  ...
# 345  0.344828                 0.16     1           1         0    0
# 361  0.379310                 0.28     1           1         0    0
# 325  0.448276                 0.36     1           1         0    0
# 282  0.827586                 0.76     1           0         1    0
# 8    0.103448                 0.04     0           1         0    0
#
# [261 rows x 6 columns]

# %%
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
rfe=RFE(lm,n_features_to_select=10 )
rfe =rfe.fit(x_train,y_train)
rfe
list(zip(x_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('Age', True, 1),
#  ('Years of Experience', True, 1),
#  ('Male', True, 1),
#  ("Bachelor's", True, 1),
#  ("Master's", True, 1),
#  ('PhD', True, 1)]

# %%
selected_column=x_train.columns[rfe.support_]
selected_column
# Out:
# Index(['Age', 'Years of Experience', 'Male', 'Bachelor's', 'Master's', 'PhD'], dtype='object')

# %%
selected_column_rfe=x_train[selected_column]
selected_column_rfe
# Out:
#           Age  Years of Experience  Male  Bachelor's  Master's  PhD
# 26   0.482759                 0.44     0           0         1    0
# 174  0.103448                 0.06     0           0         1    0
# 35   0.137931                 0.08     1           1         0    0
# 262  0.793103                 0.72     1           0         0    1
# 39   0.896552                 0.84     1           1         0    0
# ..        ...                  ...   ...         ...       ...  ...
# 345  0.344828                 0.16     1           1         0    0
# 361  0.379310                 0.28     1           1         0    0
# 325  0.448276                 0.36     1           1         0    0
# 282  0.827586                 0.76     1           0         1    0
# 8    0.103448                 0.04     0           1         0    0
#
# [261 rows x 6 columns]

# %%
import statsmodels.api as sm
selected_column_rfe=sm.add_constant(selected_column_rfe)
selected_column_rfe
# Out:
#      const       Age  Years of Experience  Male  Bachelor's  Master's  PhD
# 26     1.0  0.482759                 0.44     0           0         1    0
# 174    1.0  0.103448                 0.06     0           0         1    0
# 35     1.0  0.137931                 0.08     1           1         0    0
# 262    1.0  0.793103                 0.72     1           0         0    1
# 39     1.0  0.896552                 0.84     1           1         0    0
# ..     ...       ...                  ...   ...         ...       ...  ...
# 345    1.0  0.344828                 0.16     1           1         0    0
# 361    1.0  0.379310                 0.28     1           1         0    0
# 325    1.0  0.448276                 0.36     1           1         0    0
# 282    1.0  0.827586                 0.76     1           0         1    0
# 8      1.0  0.103448                 0.04     0           1         0    0
#
# [261 rows x 7 columns]

# %%
lm=sm.OLS(y_train,selected_column_rfe).fit()
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.898
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     448.6
# Date:                Thu, 13 Jul 2023   Prob (F-statistic):          4.09e-124
# Time:                        15:31:44   Log-Likelihood:                 327.58
# No. Observations:                 261   AIC:                            -643.2
# Df Residuals:                     255   BIC:                            -621.8
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.0015      0.013      0.117      0.907      -0.023       0.026
# ...

# %%
x_train_new=selected_column_rfe.drop(["Master's"],axis=1)
x_train_new
# Out:
#      const       Age  Years of Experience  Male  Bachelor's  PhD
# 26     1.0  0.482759                 0.44     0           0    0
# 174    1.0  0.103448                 0.06     0           0    0
# 35     1.0  0.137931                 0.08     1           1    0
# 262    1.0  0.793103                 0.72     1           0    1
# 39     1.0  0.896552                 0.84     1           1    0
# ..     ...       ...                  ...   ...         ...  ...
# 345    1.0  0.344828                 0.16     1           1    0
# 361    1.0  0.379310                 0.28     1           1    0
# 325    1.0  0.448276                 0.36     1           1    0
# 282    1.0  0.827586                 0.76     1           0    0
# 8      1.0  0.103448                 0.04     0           1    0
#
# [261 rows x 6 columns]

# %%
x_train_lm=sm.add_constant(x_train_new)
x_train_lm
# Out:
#      const       Age  Years of Experience  Male  Bachelor's  PhD
# 26     1.0  0.482759                 0.44     0           0    0
# 174    1.0  0.103448                 0.06     0           0    0
# 35     1.0  0.137931                 0.08     1           1    0
# 262    1.0  0.793103                 0.72     1           0    1
# 39     1.0  0.896552                 0.84     1           1    0
# ..     ...       ...                  ...   ...         ...  ...
# 345    1.0  0.344828                 0.16     1           1    0
# 361    1.0  0.379310                 0.28     1           1    0
# 325    1.0  0.448276                 0.36     1           1    0
# 282    1.0  0.827586                 0.76     1           0    0
# 8      1.0  0.103448                 0.04     0           1    0
#
# [261 rows x 6 columns]

# %%
lm=sm.OLS(y_train,x_train_lm).fit()
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.898
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     448.6
# Date:                Thu, 13 Jul 2023   Prob (F-statistic):          4.09e-124
# Time:                        15:31:44   Log-Likelihood:                 327.58
# No. Observations:                 261   AIC:                            -643.2
# Df Residuals:                     255   BIC:                            -621.8
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.0203      0.018      1.134      0.258      -0.015       0.056
# ...

# %%
x_train_new1=x_train_lm.drop(["PhD"],axis = 1)
x_train_new1
# Out:
#      const       Age  Years of Experience  Male  Bachelor's
# 26     1.0  0.482759                 0.44     0           0
# 174    1.0  0.103448                 0.06     0           0
# 35     1.0  0.137931                 0.08     1           1
# 262    1.0  0.793103                 0.72     1           0
# 39     1.0  0.896552                 0.84     1           1
# ..     ...       ...                  ...   ...         ...
# 345    1.0  0.344828                 0.16     1           1
# 361    1.0  0.379310                 0.28     1           1
# 325    1.0  0.448276                 0.36     1           1
# 282    1.0  0.827586                 0.76     1           0
# 8      1.0  0.103448                 0.04     0           1
#
# [261 rows x 5 columns]

# %%
x_train_lm=sm.add_constant(x_train_new1)
x_train_lm
# Out:
#      const       Age  Years of Experience  Male  Bachelor's
# 26     1.0  0.482759                 0.44     0           0
# 174    1.0  0.103448                 0.06     0           0
# 35     1.0  0.137931                 0.08     1           1
# 262    1.0  0.793103                 0.72     1           0
# 39     1.0  0.896552                 0.84     1           1
# ..     ...       ...                  ...   ...         ...
# 345    1.0  0.344828                 0.16     1           1
# 361    1.0  0.379310                 0.28     1           1
# 325    1.0  0.448276                 0.36     1           1
# 282    1.0  0.827586                 0.76     1           0
# 8      1.0  0.103448                 0.04     0           1
#
# [261 rows x 5 columns]

# %%
lm=sm.OLS(y_train,x_train_lm).fit()
print(lm.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.896
# Model:                            OLS   Adj. R-squared:                  0.895
# Method:                 Least Squares   F-statistic:                     553.8
# Date:                Thu, 13 Jul 2023   Prob (F-statistic):          1.07e-124
# Time:                        15:31:44   Log-Likelihood:                 325.66
# No. Observations:                 261   AIC:                            -641.3
# Df Residuals:                     256   BIC:                            -623.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   0.0237      0.018      1.322      0.187      -0.012       0.059
# ...

# %%
#Salary  = Age*0.4112 + Years of Experience + Male*0.0460 + Bachelor's*(-0.0918) - 0.0237

# %%
y_train_price = lm.predict(x_train_lm)
y_train_price
# Out:
# 26     0.358612
# 174    0.084856
# 35     0.059347
# 262    0.618972
# 39     0.606858
#          ...
# 345    0.169218
# 361    0.220593
# 325    0.273748
# 282    0.645550
# 8     -0.013190
# Length: 261, dtype: float64

# %%
df_test
# Out:
#       Age  Years of Experience    Salary  Male  Bachelor's  Master's  PhD
# 161  48.0                 21.0  175000.0     1           0         1    0
# 179  46.0                 20.0  170000.0     1           0         1    0
# 132  40.0                 12.0  100000.0     0           0         1    0
# 98   38.0                 10.0   90000.0     0           0         1    0
# 209  30.0                  2.0   40000.0     0           1         0    0
# ..    ...                  ...       ...   ...         ...       ...  ...
# 218  29.0                  1.5   35000.0     1           1         0    0
# 118  29.0                  3.0   45000.0     0           1         0    0
# 136  46.0                 19.0  140000.0     1           0         1    0
# 347  45.0                 19.0  180000.0     1           0         1    0
# 19   51.0                 22.0  180000.0     1           1         0    0
#
# [112 rows x 7 columns]

# %%
num_vars = ['Age','Years of Experience','Salary']
df_test[num_vars] = scaler.transform(df_test[num_vars])
print(df_test[num_vars])
# Out:
#           Age  Years of Experience    Salary
# 161  0.862069                 0.84  0.659091
# 179  0.793103                 0.80  0.636364
# 132  0.586207                 0.48  0.318182
# 98   0.517241                 0.40  0.272727
# 209  0.241379                 0.08  0.045455
# ..        ...                  ...       ...
# 218  0.206897                 0.06  0.022727
# 118  0.206897                 0.12  0.068182
# 136  0.793103                 0.76  0.500000
# 347  0.758621                 0.76  0.681818
# 19   0.965517                 0.88  0.681818
#
# [112 rows x 3 columns]

# %%
y_test = df_test.pop('Salary')
X_test = df_test

# %%
# Now let's use our model to make predictions.

# Creating X_test_new dataframe by dropping variables from X_test
X_test_new = X_test[['Age','Years of Experience','Male',"Bachelor's"]]

# Adding a constant variable
X_test_new = sm.add_constant(X_test_new)

# %%
# Making predictions
y_pred = lm.predict(X_test_new)
y_pred
# Out:
# 161    0.684526
# 179    0.643769
# 132    0.413547
# 98     0.360392
# 209    0.055925
#          ...
# 218    0.081505
# 118    0.054144
# 136    0.631371
# 347    0.617192
# 19     0.647615
# Length: 112, dtype: float64

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.9112191012119444

# %%
# Plotting y_test and y_pred to understand the spread.
fig = plt.figure()
plt.scatter(y_test,y_pred)
fig.suptitle('y_test vs y_pred', fontsize=20)              # Plot heading
plt.xlabel('y_test', fontsize=18)                          # X-label
plt.ylabel('y_pred', fontsize=16)                          # Y-label
# Out:
# Text(0, 0.5, 'y_pred')
